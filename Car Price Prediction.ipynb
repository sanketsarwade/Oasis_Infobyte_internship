# %% [markdown]
# # Introduction:
#
# During my internship at Oasis Infobyte, I had the opportunity to work on a data science project focused on car price prediction. The objective of this project was to develop a model that can accurately predict the prices of cars based on various features and attributes.
#
# To accomplish this task, I employed several Python libraries and tools. The pandas library was utilized for data manipulation and analysis, allowing me to handle and process the dataset effectively. Additionally, I utilized the urllib.request library to fetch the dataset from an external source, ensuring that I had the necessary data for analysis and modeling.
#
# For the training and evaluation of the car price prediction model, I leveraged various regression algorithms available in the scikit-learn library. These algorithms included Linear Regression, ARD Regression, Decision Tree Regression, K-Nearest Neighbors Regression, Random Forest Regression, MLP Regression, Support Vector Regression, and XGBoost Regression. Each algorithm was evaluated using performance metrics such as mean absolute error, mean squared error, median absolute error, confusion matrix, accuracy score, and R-squared score.
#
# To preprocess the data and handle categorical variables, I employed the LabelEncoder from scikit-learn. This allowed me to transform categorical features into numerical representations suitable for model training. Additionally, the StandardScaler from scikit-learn was used to normalize the numerical features, ensuring that they were on a similar scale for better model performance.
#
# To visualize and analyze the results, I utilized the matplotlib library. I created graphs and visualizations to showcase the accuracy of the different models and highlight their performance. The ggplot style was selected to provide clear and visually appealing representations of the data.
#
# Overall, this project on car price prediction during my internship at Oasis Infobyte involved employing various libraries and tools to develop and evaluate regression models for predicting car prices. The combination of data manipulation, preprocessing, model training, and visualization techniques allowed me to gain valuable insights and contribute to the development of an accurate car price prediction system.

# %%
#Import Libraries

import pandas as pd
import urllib.request
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_absolute_error ,mean_squared_error, median_absolute_error,confusion_matrix,accuracy_score,r2_score



from sklearn.linear_model import LinearRegression ,ARDRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler

import matplotlib.pyplot as plt
# make graph about Accuracy

import matplotlib.style as style

# Set the desired style
style.use('ggplot')

# %%
#Import Data

data = pd.read_csv(r"C:\Users\SANKET\OneDrive\Desktop\180 Projects\Oasis Infobyte internship\Car Price Prediction\CarPrice.csv")

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
#Data Visualization

import seaborn as sns
plt.figure(figsize=(6,5))
sns.barplot(x='fueltype',y='price', data=data)
plt.title('Price Vs Fueltype')
plt.xlabel('Fueltype')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='carlength',y='price', data=data)
plt.title(' Price Vs Length of Car')
plt.xlabel('Length of Car')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(6,5))
sns.barplot(x='enginetype',y='price', data=data)
plt.title('Price Vs Engine type')
plt.xlabel('Engine type')
plt.ylabel('Price')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(18,8))
sns.barplot(x='horsepower',y='price', data=data)
plt.title('Price Vs Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(6,5))
sns.barplot(x='cylindernumber',y='price', data=data)
plt.title('Price Vs Number of Cyliner')
plt.xlabel('Number of Cylinder')
plt.ylabel('Price')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(6,5))
sns.barplot(x='aspiration',y='price', data=data)
plt.title('Price Vs Engine type')
plt.xlabel('Engine type')
plt.ylabel('Price')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# Calculate the correlation matrix
correlation_matrix = data.corr()

# Get the top 15 correlated columns
top_correlated_columns = correlation_matrix.nlargest(15, 'price')['price'].index

# Create a subset DataFrame with only the top correlated columns
subset_data = data[top_correlated_columns]

# Calculate the correlation matrix for the subset data
subset_correlation_matrix = subset_data.corr()

# %%
#Correlation Heatmap

fig, ax = plt.subplots(figsize=(10, 8))

# Customize the colormap
cmap = sns.diverging_palette(250, 10, as_cmap=True)
sns.heatmap(subset_correlation_matrix, annot=True, cmap=cmap, linewidths=0.5, ax=ax)
ax.set_title('Top 15 Correlated Columns Heatmap')
plt.xticks(rotation=45)
plt.show()

# %%
#DataType

data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
new_df = data.copy()

# %%
# separation the data type columns [ object and numeric ]

cat = []
num = []
for i in new_df.columns:
    if new_df[i].dtypes == 'O':
        cat.append(i)
    else:
        num.append(i)

# %%
data_n=new_df[num]   # new dataframe just type numeric
data_c=new_df[cat]  # new dataframe just type object

# %%
label_encoders = {}
categorical_columns = data_c.columns  # I would recommend using columns names here if you're using pandas. If you're using numpy then stick with range(n) instead

for column in categorical_columns:
    label_encoders[column] = LabelEncoder()
    data_c[column] = label_encoders[column].fit_transform(data_c[column])

# %%
frame = [data_c, data_n]
data1 = pd.concat(frame, axis=1)

# %%
data1.head()
# Out:
#    CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0        2         1           0           1        0           2
# 1        3         1           0           1        0           2
# 2        1         1           0           1        2           2
# 3        4         1           0           0        3           1
# 4        5         1           0           0        3           0
#
#    enginelocation  enginetype  cylindernumber  fuelsystem  ...  curbweight  \
# 0               0           0               2           5  ...        2548
# 1               0           0               2           5  ...        2548
# 2               0           5               3           5  ...        2823
# 3               0           3               2           5  ...        2337
# 4               0           3               1           5  ...        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
data1.drop('CarName', axis=1, inplace= True)
data1.drop('car_ID', axis=1, inplace= True)

# %%
X = data1.drop('price', axis=1)
y= data1['price']

# %%
#Standaedisation
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=22)

# %%
#Machine Learning Models

LR = LinearRegression()
DTR = DecisionTreeRegressor()
RFR = RandomForestRegressor()
KNR = KNeighborsRegressor()
MLP = MLPRegressor()
XGB = XGBRegressor()

# %%
model1 = [LR, DTR, RFR, KNR, MLP, XGB]
d ={}

for i in model1:
    i.fit(X_train, y_train)
    pred = i.predict(X_test)
    print(i, ':', r2_score(y_test, pred)*100)
    
    d.update({str(i):i.score(X_test, y_test)*100})
# Out:
# LinearRegression() : 86.3718080969101
# DecisionTreeRegressor() : 84.64085207861187
# RandomForestRegressor() : 91.68959846813719
# KNeighborsRegressor() : 71.0714008540712
# MLPRegressor() : -215.34122851239124
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...) : 92.47506960020837

# %%
# Acuracy plot


plt.figure(figsize=(30, 6))
plt.title("Algorithm vs Accuracy")
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(d.keys(),d.values(),marker='o',color='red')
plt.show()

# %%
#XGBRegressor Has Highest Accuracy
